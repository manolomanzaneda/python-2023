# %% [markdown]
# <a href="https://colab.research.google.com/github/manolomanzaneda/python-2023/blob/main/Mantener_imagenes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from PIL import Image

# Carga la imagen
imagen = Image.open("/content/perrito.jpg")

# Muestra la imagen
plt.imshow(imagen)
plt.show()

# %%
#Per tal que no s'esborrin les imatges del google Colab, es munta un drive (només una vegada en cada sessió)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
from PIL import Image

# Carrega la imatge des de la unitat de Google Drive
imatge = Image.open("/content/drive/MyDrive/Imatges/perrito.jpg")

# Mostra la imatge
plt.imshow(imatge)
plt.show()
